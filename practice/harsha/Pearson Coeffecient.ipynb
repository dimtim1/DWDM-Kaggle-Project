# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['size']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
np.random.seed(0)
size = 300
x = np.random.normal(0, 1, size)

# %%
y = x + np.random.normal(0, 1, size)

# %%
low_noise = pd.DataFrame({"x":x,"y":y},index=None)

# %%
low_noise
# Out:
#             x         y
# 0    1.764052  0.457525
# 1    0.400157  2.058288
# 2    0.978738  0.860574
# 3    2.240893  1.560715
# 4    1.867558  2.533941
# 5   -0.977278 -1.437998
# 6    0.950088 -0.384170
# 7   -0.151357 -1.498075
# 8   -0.103219  0.590554
# 9    0.410599  0.251025
# 10   0.144044  0.010342
# 11   1.454274  2.532017
# 12   0.761038 -0.365788
# 13   0.121675 -0.609003
# 14   0.443863  0.058983
# 15   0.333674  0.428026
# 16   1.494079  1.451908
# 17  -0.205158 -0.492045
# 18   0.313068  0.251441
# 19  -0.854096 -0.961401
# 20  -2.552990 -3.272594
# 21   0.653619 -0.159374
# 22   0.864436  1.138953
# 23  -0.742165 -1.633080
# 24   2.269755  1.112399
# 25  -1.454366 -1.766658
# 26   0.045759 -0.111908
# 27  -0.187184  2.069540
# 28   1.532779  0.828079
# 29   1.469359  2.412619
# ..        ...       ...
# 270  0.399046  0.852828
# 271 -2.772593 -4.602333
# 272  1.955912  1.992918
# 273  0.390093  1.157996
# 274 -0.652409 -0.062529
# 275 -0.390953 -0.754812
# ...

# %%
low_noise.plot(x='x',y='y')

# %%
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574,
#        -2.55298982,  0.6536186 ,  0.8644362 , -0.74216502,  2.26975462,
#        -1.45436567,  0.04575852, -0.18718385,  1.53277921,  1.46935877,
#         0.15494743,  0.37816252, -0.88778575, -1.98079647, -0.34791215,
#         0.15634897,  1.23029068,  1.20237985, -0.38732682, -0.30230275,
#        -1.04855297, -1.42001794, -1.70627019,  1.9507754 , -0.50965218,
#        -0.4380743 , -1.25279536,  0.77749036, -1.61389785, -0.21274028,
#        -0.89546656,  0.3869025 , -0.51080514, -1.18063218, -0.02818223,
#         0.42833187,  0.06651722,  0.3024719 , -0.63432209, -0.36274117,
#        -0.67246045, -0.35955316, -0.81314628, -1.7262826 ,  0.17742614,
# ...

# %%
y = x + np.random.normal(0, 10, size)

# %%
high_noise = pd.DataFrame({"x":x,"y":y},index=None)

# %%
high_noise.plot(x='x',y='y')
